# %%
import matplotlib.pyplot as plt
import statistics

# %%
def castFloat(str):
    return float(str.replace(',','.'))

# %%
# Read a file and push the elements into a list
def fileToList(fileName, ini=0, end=-1):
    list = []
    try:
        file = open(fileName)
        iLine = 0
        for line in file:
            if end == -1 or (iLine >= ini and iLine <= end):
                list.append(castFloat(line))
            iLine += 1
        file.close()
    except IOError:
        print(fileName + ' could not be opened!')
    return list

# %%
# Compute the average of a list elements
def average(list):
    list.sort()
    # Remove all missing values
    while 0 in list:
        list.remove(0)
    # Validation of list size
    if len(list) == 0: return 0
    if len(list) > 2:
        del list[0]
        del list[len(list)-1]
    # computing the average
#     sum = 0
#     for number in list:
#         sum += number
#     return sum/len(list)
    return statistics.mean(list)

# %%
# Compute the standard deviation of a list elements
def stdev(list):
    list.sort()
    # Remove all missing values
    while 0 in list:
        list.remove(0)
    # Validation of list size
    if len(list) == 0: return 0
    if len(list) > 2:
        del list[0]
        del list[len(list)-1]
    # computing the average
    return statistics.stdev(list)

# %%
# Compute the mean of a list elements
def mean(list):
    list.sort()
    # Remove all missing values
    while 0 in list:
        list.remove(0)
    # Validation of list size
    if len(list) == 0: return 0
    if len(list) > 2:
        del list[0]
        del list[len(list)-1]
    # computing the mean
    sum = 0
    for number in list:
        sum += 1/number
#     return list[0]
#     return list[len(list)-1]
#     return (list[0] + list[len(list)-1]) / 2
    return len(list)/sum

# %%
# Process a set of files
def processTest(testFiles):
    data = []
    statistics = []
    for testFile in testFiles:
        data.append(fileToList(testFile))
    for j in range(len(data[0])):
        tuple = []
        for i in range(len(data)):
            tuple.append(data[i][j])
        statistics.append(average(tuple))
    return statistics

# %%
# Group elements in list
def toBuckets(data, bucketSize):
    i = 0
    sum = 0
    bucketList = []
    for element in data:
        sum += element
        i+=1
        if i == bucketSize:
            bucketList.append(sum/i)
            i = 0
            sum = 0
    return bucketList

# %%
# Print elements of list
def printList(data):
    for element in data:
        print(str(element).replace('.',','))

# %%
# This method summarizes the 10 execution of a test
def processTest(startTest, endTest, variation, typeAlg, ini=0, end=-1):
    completeData = []
    # Store the averages of the cases
    for currentTest in range(startTest, endTest):
        path = 'TESTS/TEST %d/%s/%sTime'%(currentTest, variation, typeAlg)
#         pathResult = 'TESTS/TEST %d/%s/%s.result'%(currentTest, variation, typeAlg)
        avg = average(fileToList(path, ini, end))
        currStdev = stdev(fileToList(path, ini, end)) # only usefull when endTest-startTest = 1
#         validG = average(fileToList(pathResult))
        # Add avg to array
        completeData.append(avg)
    # Computing the statistics for every case
    # In case there is only one test case, return the avg and stdev for that case
    if endTest - startTest == 1: return avg, currStdev
    # In case there are at least two test cases, return the avg of all of themn, and the stdev of all
    return average(completeData), stdev(completeData)
    
startTest = 1
endTest = 100
# processTest(startTest,endTest,'VarDividend','fts_all', 10)

# %%
bucketSize = 1

# %%
# GENERAL 100 TEST CASES
result = processTest(startTest,endTest,'.','FORALL.fts')
print('FOR ALL (FTS)  :', result)
result = processTest(startTest,endTest,'.','FORALL.index')
print('FOR ALL (Index):', result)
print()

result = processTest(startTest,endTest,'.','FORANY.fts')
print('FOR ANY (FTS)  :', result)
result = processTest(startTest,endTest,'.','FORANY.fts')
print('FOR ANY (Index):', result)
print()
# Out:
# TESTS/TEST 1/./FORALL.ftsTime could not be opened!
# TESTS/TEST 1/./FORALL.ftsTime could not be opened!
# TESTS/TEST 2/./FORALL.ftsTime could not be opened!
# TESTS/TEST 2/./FORALL.ftsTime could not be opened!
# TESTS/TEST 3/./FORALL.ftsTime could not be opened!
# TESTS/TEST 3/./FORALL.ftsTime could not be opened!
# TESTS/TEST 4/./FORALL.ftsTime could not be opened!
# TESTS/TEST 4/./FORALL.ftsTime could not be opened!
# TESTS/TEST 5/./FORALL.ftsTime could not be opened!
# TESTS/TEST 5/./FORALL.ftsTime could not be opened!
# TESTS/TEST 6/./FORALL.ftsTime could not be opened!
# TESTS/TEST 6/./FORALL.ftsTime could not be opened!
# TESTS/TEST 7/./FORALL.ftsTime could not be opened!
# TESTS/TEST 7/./FORALL.ftsTime could not be opened!
# TESTS/TEST 8/./FORALL.ftsTime could not be opened!
# TESTS/TEST 8/./FORALL.ftsTime could not be opened!
# TESTS/TEST 9/./FORALL.ftsTime could not be opened!
# TESTS/TEST 9/./FORALL.ftsTime could not be opened!
# TESTS/TEST 10/./FORALL.ftsTime could not be opened!
# TESTS/TEST 10/./FORALL.ftsTime could not be opened!
# TESTS/TEST 11/./FORALL.ftsTime could not be opened!
# TESTS/TEST 11/./FORALL.ftsTime could not be opened!
# TESTS/TEST 12/./FORALL.ftsTime could not be opened!
# TESTS/TEST 12/./FORALL.ftsTime could not be opened!
# TESTS/TEST 13/./FORALL.ftsTime could not be opened!
# TESTS/TEST 13/./FORALL.ftsTime could not be opened!
# TESTS/TEST 14/./FORALL.ftsTime could not be opened!
# TESTS/TEST 14/./FORALL.ftsTime could not be opened!
# TESTS/TEST 15/./FORALL.ftsTime could not be opened!
# TESTS/TEST 15/./FORALL.ftsTime could not be opened!
# TESTS/TEST 16/./FORALL.ftsTime could not be opened!
# TESTS/TEST 16/./FORALL.ftsTime could not be opened!
# TESTS/TEST 17/./FORALL.ftsTime could not be opened!
# TESTS/TEST 17/./FORALL.ftsTime could not be opened!
# TESTS/TEST 18/./FORALL.ftsTime could not be opened!
# TESTS/TEST 18/./FORALL.ftsTime could not be opened!
# TESTS/TEST 19/./FORALL.ftsTime could not be opened!
# TESTS/TEST 19/./FORALL.ftsTime could not be opened!
# TESTS/TEST 20/./FORALL.ftsTime could not be opened!
# TESTS/TEST 20/./FORALL.ftsTime could not be opened!
# TESTS/TEST 21/./FORALL.ftsTime could not be opened!
# TESTS/TEST 21/./FORALL.ftsTime could not be opened!
# TESTS/TEST 22/./FORALL.ftsTime could not be opened!
# TESTS/TEST 22/./FORALL.ftsTime could not be opened!
# TESTS/TEST 23/./FORALL.ftsTime could not be opened!
# TESTS/TEST 23/./FORALL.ftsTime could not be opened!
# TESTS/TEST 24/./FORALL.ftsTime could not be opened!
# TESTS/TEST 24/./FORALL.ftsTime could not be opened!
# TESTS/TEST 25/./FORALL.ftsTime could not be opened!
# TESTS/TEST 25/./FORALL.ftsTime could not be opened!
# TESTS/TEST 26/./FORALL.ftsTime could not be opened!
# TESTS/TEST 26/./FORALL.ftsTime could not be opened!
# TESTS/TEST 27/./FORALL.ftsTime could not be opened!
# TESTS/TEST 27/./FORALL.ftsTime could not be opened!
# TESTS/TEST 28/./FORALL.ftsTime could not be opened!
# TESTS/TEST 28/./FORALL.ftsTime could not be opened!
# TESTS/TEST 29/./FORALL.ftsTime could not be opened!
# TESTS/TEST 29/./FORALL.ftsTime could not be opened!
# TESTS/TEST 30/./FORALL.ftsTime could not be opened!
# TESTS/TEST 30/./FORALL.ftsTime could not be opened!
# TESTS/TEST 31/./FORALL.ftsTime could not be opened!
# TESTS/TEST 31/./FORALL.ftsTime could not be opened!
# TESTS/TEST 32/./FORALL.ftsTime could not be opened!
# TESTS/TEST 32/./FORALL.ftsTime could not be opened!
# TESTS/TEST 33/./FORALL.ftsTime could not be opened!
# TESTS/TEST 33/./FORALL.ftsTime could not be opened!
# TESTS/TEST 34/./FORALL.ftsTime could not be opened!
# TESTS/TEST 34/./FORALL.ftsTime could not be opened!
# TESTS/TEST 35/./FORALL.ftsTime could not be opened!
# TESTS/TEST 35/./FORALL.ftsTime could not be opened!
# TESTS/TEST 36/./FORALL.ftsTime could not be opened!
# TESTS/TEST 36/./FORALL.ftsTime could not be opened!
# TESTS/TEST 37/./FORALL.ftsTime could not be opened!
# TESTS/TEST 37/./FORALL.ftsTime could not be opened!
# TESTS/TEST 38/./FORALL.ftsTime could not be opened!
# TESTS/TEST 38/./FORALL.ftsTime could not be opened!
# TESTS/TEST 39/./FORALL.ftsTime could not be opened!
# TESTS/TEST 39/./FORALL.ftsTime could not be opened!
# TESTS/TEST 40/./FORALL.ftsTime could not be opened!
# TESTS/TEST 40/./FORALL.ftsTime could not be opened!
# TESTS/TEST 41/./FORALL.ftsTime could not be opened!
# TESTS/TEST 41/./FORALL.ftsTime could not be opened!
# TESTS/TEST 42/./FORALL.ftsTime could not be opened!
# TESTS/TEST 42/./FORALL.ftsTime could not be opened!
# TESTS/TEST 43/./FORALL.ftsTime could not be opened!
# TESTS/TEST 43/./FORALL.ftsTime could not be opened!
# TESTS/TEST 44/./FORALL.ftsTime could not be opened!
# TESTS/TEST 44/./FORALL.ftsTime could not be opened!
# TESTS/TEST 45/./FORALL.ftsTime could not be opened!
# TESTS/TEST 45/./FORALL.ftsTime could not be opened!
# TESTS/TEST 46/./FORALL.ftsTime could not be opened!
# TESTS/TEST 46/./FORALL.ftsTime could not be opened!
# TESTS/TEST 47/./FORALL.ftsTime could not be opened!
# TESTS/TEST 47/./FORALL.ftsTime could not be opened!
# TESTS/TEST 48/./FORALL.ftsTime could not be opened!
# TESTS/TEST 48/./FORALL.ftsTime could not be opened!
# TESTS/TEST 49/./FORALL.ftsTime could not be opened!
# TESTS/TEST 49/./FORALL.ftsTime could not be opened!
# TESTS/TEST 50/./FORALL.ftsTime could not be opened!
# TESTS/TEST 50/./FORALL.ftsTime could not be opened!
# TESTS/TEST 51/./FORALL.ftsTime could not be opened!
# TESTS/TEST 51/./FORALL.ftsTime could not be opened!
# TESTS/TEST 52/./FORALL.ftsTime could not be opened!
# TESTS/TEST 52/./FORALL.ftsTime could not be opened!
# TESTS/TEST 53/./FORALL.ftsTime could not be opened!
# TESTS/TEST 53/./FORALL.ftsTime could not be opened!
# TESTS/TEST 54/./FORALL.ftsTime could not be opened!
# TESTS/TEST 54/./FORALL.ftsTime could not be opened!
# TESTS/TEST 55/./FORALL.ftsTime could not be opened!
# TESTS/TEST 55/./FORALL.ftsTime could not be opened!
# TESTS/TEST 56/./FORALL.ftsTime could not be opened!
# TESTS/TEST 56/./FORALL.ftsTime could not be opened!
# TESTS/TEST 57/./FORALL.ftsTime could not be opened!
# TESTS/TEST 57/./FORALL.ftsTime could not be opened!
# TESTS/TEST 58/./FORALL.ftsTime could not be opened!
# TESTS/TEST 58/./FORALL.ftsTime could not be opened!
# TESTS/TEST 59/./FORALL.ftsTime could not be opened!
# TESTS/TEST 59/./FORALL.ftsTime could not be opened!
# TESTS/TEST 60/./FORALL.ftsTime could not be opened!
# TESTS/TEST 60/./FORALL.ftsTime could not be opened!
# TESTS/TEST 61/./FORALL.ftsTime could not be opened!
# TESTS/TEST 61/./FORALL.ftsTime could not be opened!
# TESTS/TEST 62/./FORALL.ftsTime could not be opened!
# TESTS/TEST 62/./FORALL.ftsTime could not be opened!
# TESTS/TEST 63/./FORALL.ftsTime could not be opened!
# TESTS/TEST 63/./FORALL.ftsTime could not be opened!
# TESTS/TEST 64/./FORALL.ftsTime could not be opened!
# TESTS/TEST 64/./FORALL.ftsTime could not be opened!
# TESTS/TEST 65/./FORALL.ftsTime could not be opened!
# TESTS/TEST 65/./FORALL.ftsTime could not be opened!
# TESTS/TEST 66/./FORALL.ftsTime could not be opened!
# TESTS/TEST 66/./FORALL.ftsTime could not be opened!
# TESTS/TEST 67/./FORALL.ftsTime could not be opened!
# TESTS/TEST 67/./FORALL.ftsTime could not be opened!
# TESTS/TEST 68/./FORALL.ftsTime could not be opened!
# TESTS/TEST 68/./FORALL.ftsTime could not be opened!
# TESTS/TEST 69/./FORALL.ftsTime could not be opened!
# TESTS/TEST 69/./FORALL.ftsTime could not be opened!
# TESTS/TEST 70/./FORALL.ftsTime could not be opened!
# TESTS/TEST 70/./FORALL.ftsTime could not be opened!
# TESTS/TEST 71/./FORALL.ftsTime could not be opened!
# TESTS/TEST 71/./FORALL.ftsTime could not be opened!
# TESTS/TEST 72/./FORALL.ftsTime could not be opened!
# TESTS/TEST 72/./FORALL.ftsTime could not be opened!
# TESTS/TEST 73/./FORALL.ftsTime could not be opened!
# TESTS/TEST 73/./FORALL.ftsTime could not be opened!
# TESTS/TEST 74/./FORALL.ftsTime could not be opened!
# TESTS/TEST 74/./FORALL.ftsTime could not be opened!
# TESTS/TEST 75/./FORALL.ftsTime could not be opened!
# TESTS/TEST 75/./FORALL.ftsTime could not be opened!
# TESTS/TEST 76/./FORALL.ftsTime could not be opened!
# TESTS/TEST 76/./FORALL.ftsTime could not be opened!
# TESTS/TEST 77/./FORALL.ftsTime could not be opened!
# TESTS/TEST 77/./FORALL.ftsTime could not be opened!
# TESTS/TEST 78/./FORALL.ftsTime could not be opened!
# TESTS/TEST 78/./FORALL.ftsTime could not be opened!
# TESTS/TEST 79/./FORALL.ftsTime could not be opened!
# TESTS/TEST 79/./FORALL.ftsTime could not be opened!
# TESTS/TEST 80/./FORALL.ftsTime could not be opened!
# TESTS/TEST 80/./FORALL.ftsTime could not be opened!
# TESTS/TEST 81/./FORALL.ftsTime could not be opened!
# TESTS/TEST 81/./FORALL.ftsTime could not be opened!
# TESTS/TEST 82/./FORALL.ftsTime could not be opened!
# TESTS/TEST 82/./FORALL.ftsTime could not be opened!
# TESTS/TEST 83/./FORALL.ftsTime could not be opened!
# TESTS/TEST 83/./FORALL.ftsTime could not be opened!
# TESTS/TEST 84/./FORALL.ftsTime could not be opened!
# TESTS/TEST 84/./FORALL.ftsTime could not be opened!
# TESTS/TEST 85/./FORALL.ftsTime could not be opened!
# TESTS/TEST 85/./FORALL.ftsTime could not be opened!
# TESTS/TEST 86/./FORALL.ftsTime could not be opened!
# TESTS/TEST 86/./FORALL.ftsTime could not be opened!
# TESTS/TEST 87/./FORALL.ftsTime could not be opened!
# TESTS/TEST 87/./FORALL.ftsTime could not be opened!
# TESTS/TEST 88/./FORALL.ftsTime could not be opened!
# TESTS/TEST 88/./FORALL.ftsTime could not be opened!
# TESTS/TEST 89/./FORALL.ftsTime could not be opened!
# TESTS/TEST 89/./FORALL.ftsTime could not be opened!
# TESTS/TEST 90/./FORALL.ftsTime could not be opened!
# TESTS/TEST 90/./FORALL.ftsTime could not be opened!
# TESTS/TEST 91/./FORALL.ftsTime could not be opened!
# TESTS/TEST 91/./FORALL.ftsTime could not be opened!
# TESTS/TEST 92/./FORALL.ftsTime could not be opened!
# TESTS/TEST 92/./FORALL.ftsTime could not be opened!
# TESTS/TEST 93/./FORALL.ftsTime could not be opened!
# TESTS/TEST 93/./FORALL.ftsTime could not be opened!
# TESTS/TEST 94/./FORALL.ftsTime could not be opened!
# TESTS/TEST 94/./FORALL.ftsTime could not be opened!
# TESTS/TEST 95/./FORALL.ftsTime could not be opened!
# TESTS/TEST 95/./FORALL.ftsTime could not be opened!
# TESTS/TEST 96/./FORALL.ftsTime could not be opened!
# TESTS/TEST 96/./FORALL.ftsTime could not be opened!
# TESTS/TEST 97/./FORALL.ftsTime could not be opened!
# TESTS/TEST 97/./FORALL.ftsTime could not be opened!
# TESTS/TEST 98/./FORALL.ftsTime could not be opened!
# TESTS/TEST 98/./FORALL.ftsTime could not be opened!
# TESTS/TEST 99/./FORALL.ftsTime could not be opened!
# TESTS/TEST 99/./FORALL.ftsTime could not be opened!
# FOR ALL (FTS)  : (0, 0)
# ---------------------------------------------------------------------------
# StatisticsError                           Traceback (most recent call last)
# <ipython-input-12-f462f2c7fc8a> in <module>
#       2 result = processTest(startTest,endTest,'.','FORALL.fts')
#       3 print('FOR ALL (FTS)  :', result)
# ----> 4 result = processTest(startTest,endTest,'.','FORALL.index')
#       5 print('FOR ALL (Index):', result)
#       6 print()
#
# <ipython-input-10-b46856fd146e> in processTest(startTest, endTest, variation, typeAlg, ini, end)
#       7 #         pathResult = 'TESTS/TEST %d/%s/%s.result'%(currentTest, variation, typeAlg)
#       8         avg = average(fileToList(path, ini, end))
# ----> 9         currStdev = stdev(fileToList(path, ini, end)) # only usefull when endTest-startTest = 1
#      10 #         validG = average(fileToList(pathResult))
#      11         # Add avg to array
#
# <ipython-input-5-88d6cb37fcd3> in stdev(list)
#      11         del list[len(list)-1]
#      12     # computing the average
# ---> 13     return statistics.stdev(list)
#
# ~/anaconda3/lib/python3.7/statistics.py in stdev(data, xbar)
#     647
#     648     """
# --> 649     var = variance(data, xbar)
#     650     try:
#     651         return var.sqrt()
#
# ~/anaconda3/lib/python3.7/statistics.py in variance(data, xbar)
#     585     n = len(data)
#     586     if n < 2:
# --> 587         raise StatisticsError('variance requires at least two data points')
#     588     T, ss = _ss(data, xbar)
#     589     return _convert(ss/(n-1), T)
#
# StatisticsError: variance requires at least two data points

# %%
# GENERAL 100 TEST CASES
result = processTest(1,2,'.','FORALL.fts')
print('FOR ALL (FTS)  :', result)
result = processTest(1,2,'.','FORALL.index')
print('FOR ALL (Index):', result)
print()

result = processTest(1,2,'.','FORANY.fts')
print('FOR ANY (FTS)  :', result)
result = processTest(1,2,'.','FORANY.fts')
print('FOR ANY (Index):', result)
print()
