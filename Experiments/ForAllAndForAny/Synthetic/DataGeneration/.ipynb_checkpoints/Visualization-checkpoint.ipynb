# %%
import matplotlib.pyplot as plt

# %%
def castFloat(str):
    return float(str.replace(',','.'))

# %%
# Read a file and push the elements into a list
def fileToList(fileName):
    list = []
    try:
        file = open(fileName)
        for line in file:
            list.append(castFloat(line))
        file.close()
    except IOError:
        errorMsg = fileName + ' could not be opened!'
        print(errorMsg)
    return list

# %%
# Compute the average of a list elements
def average(list):
#     list.sort()
#     # Remove all missing values
#     while 0 in list:
#         list.remove(0)
#     # Validation of list size
    if len(list) <= 0: return 0
#     if len(list) > 2:
#         del list[0]
#         del list[len(list)-1]
#     # computing the average
    sum = 0
    size = 0
    for number in list:
        if number > 0:
            sum += number
            size += 1
    return 0 if size == 0 else sum/size

# %%
# Compute the mean of a list elements
def mean(list):
    list.sort()
    # Remove all missing values
    while 0 in list:
        list.remove(0)
    # Validation of list size
    if len(list) <= 2: return 0
    if len(list) > 2:
        del list[0]
        del list[len(list)-1]
    # computing the mean
    sum = 0
    for number in list:
        sum += 1/number
#     return list[0]
#     return list[len(list)-1]
#     return (list[0] + list[len(list)-1]) / 2
    return len(list)/sum

# %%
# Process a set of files
def processTest(testFiles):
    data = []
    statistics = []
    for testFile in testFiles:
        data.append(fileToList(testFile))
    for j in range(len(data[0])):
        tuple = []
        for i in range(len(data)):
            tuple.append(data[i][j])
        statistics.append(average(tuple))
    return statistics

# %%
# Group elements in list
def toBuckets(data, bucketSize):
    i = 0
    sum = 0
    bucketList = []
    for element in data:
        sum += element
        i+=1
        if i == bucketSize:
            bucketList.append(sum/i)
            i = 0
            sum = 0
    return bucketList

# %%
# Print elements of list
def printList(data):
    for element in data:
        if element != 0:
            print(str(element).replace('.',','))
        else:
            print('null')

# %%
# This method summarizes the 10 execution of a test
def processTest(startTest, endTest, variation, typeAlg, nrCasesXVar, orderByValidG = False):
    completeData = []
    difs = 0
    # Append nrCasesXVar empty lists
    for i in range(nrCasesXVar):
        completeData.append([])
    # Store the averages of the cases
    for currentTest in range(startTest, endTest):
        for i in range(nrCasesXVar):
            path = 'TESTS/TEST %d/%s/%d/%s.time'%(currentTest, variation, i+1, typeAlg)
            pathResult = 'TESTS/TEST %d/%s/%d/%s.result'%(currentTest, variation, i+1, typeAlg)
            avg = average(fileToList(path))
#             validG = average(fileToList(pathResult))
#             # If order by valid groups
#             if orderByValidG: 
#                 # Limit of tuples in set
#                 if validG > 0 and validG <= 100:# and len(completeData[int(validG)-1]) < 50:
#                     completeData[int(validG)-1].append(avg)
#             # Default order
#             else:
            completeData[i].append(avg)
    
#     return completeData
    # Computing the statistics for every case
    statistics = []
    for tuple in completeData:
#         print('---->', len(tuple))
        statistics.append(average(tuple))
            
#     print(completeData)
#     print(statistics)
#     print(difs)
    return statistics
    
startTest = 1
endTest = 2
# processTest(startTest,endTest,'VarDividend','fts_all', 10)

# %%
def findDifs(startTest, endTest, variation, typesAlg, nrCasesXVar, isDbg = False):
    difs = 0
    total = 0
    # Store the averages of the cases
    for currentTest in range(startTest, endTest):
        for i in range(nrCasesXVar):
            pathResult1 = 'TESTS/TEST %d/%s/%d/%s.result'%(currentTest, variation, i+1, typesAlg[0])
            pathResult2 = 'TESTS/TEST %d/%s/%d/%s.result'%(currentTest, variation, i+1, typesAlg[1])
            validG1 = average(fileToList(pathResult1))
            validG2 = average(fileToList(pathResult2))
            if validG1 != validG2:
                if isDbg:
                    print('Dif At TESTS/TEST %d/%s/%d: %d vs %d'%(currentTest, variation, i+1, validG1, validG2))
                difs += 1
            total += 1    
    return difs, total

# %%
bucketSize = 1
wantToPlot = True
nr_steps = 50

# %%
findDifs(startTest,endTest,'VarT1',['fts_all', 'index_all'], nr_steps, True)
# Out:
# TESTS/TEST 1/VarT1/1/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/2/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/3/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/4/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/5/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/6/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/7/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/8/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/9/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/10/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/11/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/12/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/13/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/14/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/15/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/16/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/17/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/18/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/19/fts_all.result could not be opened!
# TESTS/TEST 1/VarT1/20/fts_all.result could not be opened!
# (0, 20)

# %%
result = processTest(startTest,endTest,'VarT1','fts_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarT1/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarT1/20/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarT1','fts_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarT1/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarT1/20/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarT1','index_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarT1','index_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarT2','fts_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarT2/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarT2/20/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarT2','fts_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarT2/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarT2/20/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarT2','index_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarT2','index_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarTG','fts_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarTG/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarTG/20/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarTG','fts_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarTG/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarTG/20/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarTG','index_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarTG','index_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarL1L2','fts_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarL1L2/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarL1L2/20/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarL1L2','fts_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarL1L2/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarL1L2/20/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarL1L2','index_all', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarL1L2','index_any', nr_steps)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarDistribution','fts_all', nr_steps*3)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarDistribution/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/20/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/21/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/22/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/23/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/24/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/25/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/26/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/27/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/28/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/29/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/30/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/31/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/32/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/33/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/34/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/35/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/36/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/37/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/38/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/39/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/40/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/41/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/42/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/43/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/44/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/45/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/46/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/47/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/48/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/49/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/50/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/51/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/52/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/53/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/54/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/55/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/56/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/57/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/58/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/59/fts_all.time could not be opened!
# TESTS/TEST 1/VarDistribution/60/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarDistribution','fts_any', nr_steps*3)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarDistribution/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/20/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/21/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/22/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/23/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/24/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/25/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/26/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/27/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/28/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/29/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/30/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/31/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/32/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/33/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/34/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/35/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/36/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/37/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/38/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/39/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/40/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/41/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/42/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/43/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/44/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/45/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/46/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/47/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/48/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/49/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/50/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/51/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/52/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/53/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/54/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/55/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/56/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/57/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/58/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/59/fts_any.time could not be opened!
# TESTS/TEST 1/VarDistribution/60/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarDistribution','index_all', nr_steps*3)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarDistribution','index_any', nr_steps*3)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
result = processTest(startTest,endTest,'VarValidGroupsForAll','fts_all', nr_steps, True)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarValidGroupsForAll/1/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/2/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/3/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/4/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/5/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/6/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/7/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/8/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/9/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/10/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/11/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/12/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/13/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/14/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/15/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/16/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/17/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/18/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/19/fts_all.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/20/fts_all.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarValidGroupsForAll','fts_any', nr_steps, True)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
# Out:
# TESTS/TEST 1/VarValidGroupsForAll/1/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/2/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/3/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/4/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/5/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/6/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/7/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/8/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/9/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/10/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/11/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/12/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/13/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/14/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/15/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/16/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/17/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/18/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/19/fts_any.time could not be opened!
# TESTS/TEST 1/VarValidGroupsForAll/20/fts_any.time could not be opened!

# %%
result = processTest(startTest,endTest,'VarValidGroupsForAll','index_all', nr_steps, True)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)

# %%
# startTest = 14
# endTest = 15
result = processTest(startTest,endTest,'VarValidGroupsForAny','index_any', nr_steps, True)
result = toBuckets(result, bucketSize)
if wantToPlot:
    plt.plot(result)
else:
    printList(result)
